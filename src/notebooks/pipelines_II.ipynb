# %% [markdown]
# ## Cargamos datos y modelos, y probamos contra test

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import funtions_import_merge as preprocess

import importlib

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn import metrics

import pickle
from sklearn.metrics import classification_report

# %%
# Recargamos el módulo de funciones para evitar errores en Jupyter notebook
importlib.reload(preprocess)
# Out:
# <module 'funtions_import_merge' from 'c:\\Users\\josea\\github\\S2_ML_LAI_Estimation\\src\\notebooks\\funtions_import_merge.py'>

# %%
file_name_sat = 'S2_SR_USA_2017_2024_SCL.csv'
#file_name_sat = 'S2_TOArefl_USA_2017_2024.csv'
file_name_insitu = 'NEON_LAI_USA_2017_2024.csv'

# %% [markdown]
# ### 1. Datos de satelite

# %% [markdown]
# Cargamos el dataset de adquisiciones de satelite

# %%
df_sat = preprocess.satellite_import(file_name_sat)
df_sat.head(5)
# Out:
#                                         id  longitude   latitude  \
# 23  20190128T154519_20190128T154758_T19TCJ -71.287337  44.063892
# 24  20190128T154519_20190128T154758_T18TYP -71.287337  44.063892
# 33  20190222T154241_20190222T154730_T19TCJ -71.287337  44.063892
# 34  20190222T154241_20190222T154730_T18TYP -71.287337  44.063892
# 63  20190508T153819_20190508T154933_T19TCJ -71.287337  44.063892
#
#                       time     B1      B2      B3      B4      B5      B6  \
# 23 2019-01-28 15:50:57.000  447.0  0.0543  0.0520  0.0584  0.0665  0.1536
# 24 2019-01-28 15:51:01.000  240.0  0.0251  0.0346  0.0358  0.0649  0.1531
# 33 2019-02-22 15:50:52.000  592.0  0.0642  0.0854  0.0816  0.0890  0.1784
# 34 2019-02-22 15:50:56.000  457.0  0.0438  0.0541  0.0619  0.0842  0.1787
# 63 2019-05-08 15:51:05.057  294.0  0.0388  0.0560  0.0564  0.0942  0.1683
#
#     ...      B8     B8A      B9     B11     B12  SCL  QA10  QA20  QA60  \
# 23  ...  0.2460  0.2054  2135.0  0.0793  0.0550  4.0   0.0   0.0     0
# 24  ...  0.2365  0.2108  2132.0  0.0815  0.0570  4.0   0.0   0.0     0
# 33  ...  0.2199  0.2268  2616.0  0.1014  0.0616  4.0   0.0   0.0     0
# 34  ...  0.1845  0.2290  2654.0  0.1034  0.0623  4.0   0.0   0.0     0
# 63  ...  0.2432  0.2120  2289.0  0.1615  0.0985  4.0   0.0   0.0     0
#
#                         Site_sat
# 23  Bartlett Experimental Forest
# 24  Bartlett Experimental Forest
# 33  Bartlett Experimental Forest
# 34  Bartlett Experimental Forest
# 63  Bartlett Experimental Forest
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 2. Datos de campo

# %% [markdown]
# Cargamos el dataset de medidas insitu.

# %%
df_insitu = preprocess.insitu_import(file_name_insitu)
df_insitu.head(5)
# Out:
#           GBOV_ID            Site  GROUND_DATA_PI       GROUND_DATA_PIs_Email  \
# 0   GBOV_RM7_1223  Harvard Forest  Courtney Meier  cmeier@battelleecology.org
# 2   GBOV_RM7_1235  Harvard Forest  Courtney Meier  cmeier@battelleecology.org
# 6   GBOV_RM7_1211  Harvard Forest  Courtney Meier  cmeier@battelleecology.org
# 8   GBOV_RM7_1253  Harvard Forest  Courtney Meier  cmeier@battelleecology.org
# 10  GBOV_RM7_1247  Harvard Forest  Courtney Meier  cmeier@battelleecology.org
#
#                             GBOV_Email Network  Elevation    IGBP_class  \
# 0   support-copernicus-gbov@acri-st.fr    NEON        351  Mixed Forest
# 2   support-copernicus-gbov@acri-st.fr    NEON        351  Mixed Forest
# 6   support-copernicus-gbov@acri-st.fr    NEON        351  Mixed Forest
# 8   support-copernicus-gbov@acri-st.fr    NEON        351  Mixed Forest
# 10  support-copernicus-gbov@acri-st.fr    NEON        351  Mixed Forest
#
#      Lat_IS     Lon_IS  ... clumping_Miller_down  clumping_Warren_down  \
# 0   42.5378 -72.171501  ...                 0.75                  0.80
# 2   42.5378 -72.171501  ...                 0.76                  0.74
# 6   42.5378 -72.171501  ...                 0.74                  0.79
# 8   42.5378 -72.171501  ...                 0.77                  0.83
# 10  42.5378 -72.171501  ...                 0.71                  0.72
#
#     clumping_Miller_up_err  clumping_Warren_up_err  clumping_Miller_down_err  \
# 0                    0.029                    0.04                      0.11
# 2                    0.033                    0.05                      0.08
# 6                    0.029                    0.05                      0.05
# 8                    0.030                    0.05                      0.08
# 10                   0.029                    0.06                      0.10
#
#     clumping_Warren_down_err  Warren_up_flag  Warren_down_flag  LAI_Warren  \
# 0                       0.19             0.0               0.0        3.89
# 2                       0.17             0.0               0.0        5.37
# 6                       0.09             0.0               0.0        5.95
# 8                       0.14             0.0               0.0        5.47
# 10                      0.22             0.0               0.0        4.79
#
#     LAI_Warren_err
# 0             0.19
# 2             0.41
# 6             0.29
# 8             0.30
# 10            0.44
#
# [5 rows x 42 columns]

# %% [markdown]
# ### 3. Combinación de los datasets

# %% [markdown]
# **Merge de data sets**. Para cada site identificamos las medidas in_situ mas cercanas a la fecha de adquisicion del satélite

# %%
df_cross = preprocess.merge_datasets(df_sat,df_insitu)
df_cross.head(5)
# Out:
#                                        id  longitude   latitude  \
# 0  20190607T153819_20190607T154303_T18TYN -72.171458  42.537834
# 1  20190627T153819_20190627T154123_T18TYN -72.171458  42.537834
# 2  20190712T153911_20190712T154425_T18TYN -72.171458  42.537834
# 3  20190801T153911_20190801T154113_T18TYN -72.171458  42.537834
# 4  20190826T153819_20190826T154455_T18TYN -72.171458  42.537834
#
#                      time     B1      B2      B3      B4      B5      B6  ...  \
# 0 2019-06-07 15:51:23.000  166.0  0.0198  0.0532  0.0169  0.0982  0.3507  ...
# 1 2019-06-27 15:51:23.000  233.0  0.0236  0.0405  0.0193  0.0782  0.3244  ...
# 2 2019-07-12 15:51:20.431  288.0  0.0197  0.0203  0.0126  0.0247  0.0888  ...
# 3 2019-08-01 15:51:19.875  228.0  0.0176  0.0422  0.0188  0.0757  0.3112  ...
# 4 2019-08-26 15:51:19.743  174.0  0.0204  0.0405  0.0182  0.0711  0.2746  ...
#
#    clumping_Warren_up_err  clumping_Miller_down_err  clumping_Warren_down_err  \
# 0                    0.04                      0.09                      0.15
# 1                    0.04                      0.10                      0.19
# 2                    0.04                      0.11                      0.18
# 3                    0.05                      0.08                      0.15
# 4                    0.05                      0.06                      0.09
#
#    Warren_up_flag  Warren_down_flag  LAI_Warren  LAI_Warren_err  \
# 0             0.0               0.0       4.030           0.170
# 1             0.0               0.0       4.820           0.220
# 2             0.0               0.0       3.871           0.195
# 3             0.0               0.0       3.790           0.210
# 4             0.0               0.0       4.281           0.219
#
#                    delta    date_sat  date_insitu
# 0        3 days 10:17:23  2019-06-07   2019-06-04
# 1        4 days 13:44:37  2019-06-27   2019-07-02
# 2 3 days 13:53:39.569000  2019-07-12   2019-07-16
# 3 2 days 09:45:19.875000  2019-08-01   2019-07-30
# 4 0 days 14:23:40.257000  2019-08-26   2019-08-27
#
# [5 rows x 66 columns]

# %% [markdown]
# ### Definimos X_test y y_test

# %% [markdown]
# Elegimos fechas del dataset. Nos quedamos con los datos del 2023

# %%
test_set = df_cross[pd.to_datetime(df_cross['date_insitu']) >= pd.to_datetime('2023-01-01')].copy()

# %% [markdown]
# Definimos X_train & y_train

# %%
X_test = test_set.drop('LAI_Warren', axis=1)
y_test = test_set['LAI_Warren']

# %%
# Recuperamos el modelo de pipelines (version pickle)
with open('../models/modelo_pipeline.pkl', 'rb') as archivo:
    modelo_pipeline = pickle.load(archivo)

# %%
modelo_pipeline
# Out:
# Pipeline(steps=[('pipe_exclude_columns',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('excluye', 'drop',
#                                                   ['id', 'longitude',
#                                                    'latitude', 'time', 'B1',
#                                                    'B9', 'SCL', 'QA10', 'QA20',
#                                                    'QA60', 'Site_sat',
#                                                    'GBOV_ID', 'Site',
#                                                    'GROUND_DATA_PI',
#                                                    'GROUND_DATA_PIs_Email',
#                                                    'GBOV_Email', 'Network',
#                                                    'Elevation', 'IGBP_class',
#                                                    'Lat_IS', 'Lon_IS',
#                                                    'TIME_IS', 'Version',
#                                                    'up_flag', 'down_flag',
#                                                    'LAI_Miller_up',
#                                                    'LAI_Warren_up',
#                                                    'LAIe_Miller_up',
#                                                    'LAIe_Warren_up',
#                                                    'LAI_Miller_down', ...])])),
#                 ('SScaler', StandardScaler()), ('Modelo', LinearRegression())])

# %% [markdown]
# ### Prueba modelo contra test

# %%
y_pred = modelo_pipeline.predict(X_test)

argumentos = (y_test, y_pred)

print('MSE:', metrics.mean_squared_error(*argumentos))
print('RMSE:', np.sqrt(metrics.mean_squared_error(*argumentos)))
print('MAE:', metrics.mean_absolute_error(*argumentos))
print('MAPE:', metrics.mean_absolute_percentage_error(*argumentos))
print('R2:', modelo_pipeline.score(X_test, y_test))
# Out:
# MSE: 0.8667197303415693
# RMSE: 0.9309778355801868
# MAE: 0.7428809228396843
# MAPE: 0.5725172311928037
# R2: 0.761551862776899

# %%
df_result = pd.DataFrame(y_test)
df_result['pred'] = y_pred
df_result['Class'] = test_set['IGBP_class']

# %%
plt.figure(figsize=(7, 7))

# Scatter plot
sns.scatterplot(data=df_result, x="LAI_Warren", y="pred", hue="Class")

# Línea de identidad
x_vals = [0, 8]
plt.plot(x_vals, x_vals, 'k--', lw=2)

# Sombra entre y = x - 1 y y = x + 1
plt.fill_between(x_vals,
                 [x - 1 for x in x_vals],
                 [x + 1 for x in x_vals],
                 color='gray', alpha=0.3, label='±1 margen')

plt.xlim(0, 8)
plt.ylim(0, 8)
#plt.axis('square')

plt.xlabel('Valores Reales')
plt.ylabel('Predicciones')
plt.title('Comparación de Predicciones vs Valores Reales')
plt.legend()

# Mover la leyenda fuera del gráfico
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.tight_layout()  # Ajusta automáticamente para que no se corte nada

plt.show()
